# %% [markdown]
# # Welcome to the 2024   Python Course!
#
# ## ARIES and Cefas
#
# [Course website](https://ueapy.github.io/pythoncourse2024-website/programme/)
#
# [Course material on github](https://github.com/ueapy/pythoncourse2024-materials)

# %% [markdown]
# ## ARIES
#
# <https://www.aries-dtp.ac.uk/>
#
# ## Cefas
#
# <https://www.cefas.co.uk/>
#
#
# ## Your teachers and organisers for this course:
#
#     Alice Hsu - UEA-ENV
#     Claire Beraud - Cefas
#     Eilean Macdonald
#     Eliza Karlowska - UEA-ENV
#     James Scott - Cefas
#     Jenny Graham - Cefas
#     Matthew Thomas - Cefas
#     Rob McEwan - Cefas
#     Tiago Silva - Cefas

# %% [markdown]
# [//]: # (### WiFi: * eduroam - for uea accounts * The_Cloud - sign up for a free Sky account)
