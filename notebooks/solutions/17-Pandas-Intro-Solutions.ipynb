# %% [markdown]
# # Pandas Solutions

# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import warnings
warnings.filterwarnings('ignore')

fname = '../../data/air_quality_hourly_london_marylebone.csv'

def dateparse(date_str, time_str):
    if time_str == '24:00:00':
        time_str = '00:00:00'
        date = pd.datetime.strptime(date_str + time_str, '%Y-%m-%d%H:%M:%S')
        date = date + datetime.timedelta(days=1)
    else:
        date = pd.datetime.strptime(date_str + time_str, '%Y-%m-%d%H:%M:%S')
    return date 
    #pd.datetime.strptime(date_str + time_str, '%Y-%m-%d%H:%M:%S')

air_quality = pd.read_csv(fname, header=4, skipfooter=4, na_values='No data', engine='python',
              parse_dates={'Time': [0, 1]}, date_parser=dateparse) 


air_quality.columns = ['Time', 'O3', 'O3_status', 'NOx', 'NOx_status',
                       'CO', 'CO_status', 'PM10', 'PM10_status', 'Co', 'Co_status']

air_quality.drop('Co', 1, inplace=True)
air_quality.drop('Co_status', 1, inplace=True)

air_quality.head(4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\mambaforge\envs\course2025\Lib\site-packages\pandas\io\parsers\base_parser.py:1190, in _make_date_converter.<locals>.converter(col, *date_cols)
#    1184 warnings.filterwarnings(
#    1185     "ignore",
#    1186     ".*parsing datetimes with mixed time zones "
#    1187     "will raise an error",
#    1188     category=FutureWarning,
#    1189 )
# -> 1190 pre_parsed = date_parser(
#    1191     *(unpack_if_single_element(arg) for arg in date_cols)
#    1192 )
#    1193 try:
#
# Cell In[3], line 13, in dateparse(date_str, time_str)
#      12 def dateparse(date_str, time_str):
# ---> 13     if time_str == '24:00:00':
#      14         time_str = '00:00:00'
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 22
#      19     return date
#      20     #pd.datetime.strptime(date_str + time_str, '%Y-%m-%d%H:%M:%S')
# ---> 22 air_quality = pd.read_csv(fname, header=4, skipfooter=4, na_values='No data', engine='python',
#      23               parse_dates={'Time': [0, 1]}, date_parser=dateparse)
#      26 air_quality.columns = ['Time', 'O3', 'O3_status', 'NOx', 'NOx_status',
#      27                        'CO', 'CO_status', 'PM10', 'PM10_status', 'Co', 'Co_status']
#      29 air_quality.drop('Co', 1, inplace=True)
#
# File ~\AppData\Local\mambaforge\envs\course2025\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\mambaforge\envs\course2025\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~\AppData\Local\mambaforge\envs\course2025\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~\AppData\Local\mambaforge\envs\course2025\Lib\site-packages\pandas\io\parsers\python_parser.py:292, in PythonParser.read(self, rows)
#     289 data, columns = self._exclude_implicit_index(alldata)
#     291 conv_data = self._convert_data(data)
# --> 292 columns, conv_data = self._do_date_conversions(columns, conv_data)
#     294 index, result_columns = self._make_index(
#     295     conv_data, alldata, columns, indexnamerow
#     296 )
#     298 return index, result_columns, conv_data
#
# File ~\AppData\Local\mambaforge\envs\course2025\Lib\site-packages\pandas\io\parsers\base_parser.py:880, in ParserBase._do_date_conversions(self, names, data)
#     871 @final
#     872 def _do_date_conversions(
#     873     self,
#    (...)    876 ) -> tuple[Sequence[Hashable] | Index, Mapping[Hashable, ArrayLike] | DataFrame]:
#     877     # returns data, columns
#     879     if self.parse_dates is not None:
# --> 880         data, names = _process_date_conversion(
#     881             data,
#     882             self._date_conv,
#     883             self.parse_dates,
#     884             self.index_col,
#     885             self.index_names,
#     886             names,
#     887             keep_date_col=self.keep_date_col,
#     888             dtype_backend=self.dtype_backend,
#     889         )
#     891     return names, data
#
# File ~\AppData\Local\mambaforge\envs\course2025\Lib\site-packages\pandas\io\parsers\base_parser.py:1334, in _process_date_conversion(data_dict, converter, parse_spec, index_col, index_names, columns, keep_date_col, dtype_backend)
#    1331 if new_name in data_dict:
#    1332     raise ValueError(f"Date column {new_name} already in dict")
# -> 1334 _, col, old_names = _try_convert_dates(
#    1335     converter,
#    1336     colspec,
#    1337     data_dict,
#    1338     orig_names,
#    1339     target_name=new_name,
#    1340 )
#    1342 new_data[new_name] = col
#    1344 # If original column can be converted to date we keep the converted values
#    1345 # This can only happen if values are from single column
#
# File ~\AppData\Local\mambaforge\envs\course2025\Lib\site-packages\pandas\io\parsers\base_parser.py:1387, in _try_convert_dates(parser, colspec, data_dict, columns, target_name)
#    1384     new_name = "_".join([str(x) for x in colnames])
#    1385 to_parse = [np.asarray(data_dict[c]) for c in colnames if c in data_dict]
# -> 1387 new_col = parser(*to_parse, col=new_name if target_name is None else target_name)
#    1388 return new_name, new_col, colnames
#
# File ~\AppData\Local\mambaforge\envs\course2025\Lib\site-packages\pandas\io\parsers\base_parser.py:1213, in _make_date_converter.<locals>.converter(col, *date_cols)
#    1206 with warnings.catch_warnings():
#    1207     warnings.filterwarnings(
#    1208         "ignore",
#    1209         ".*parsing datetimes with mixed time zones "
#    1210         "will raise an error",
#    1211         category=FutureWarning,
#    1212     )
# -> 1213     pre_parsed = parsing.try_parse_dates(
#    1214         parsing.concat_date_cols(date_cols),
#    1215         parser=date_parser,
#    1216     )
#    1217     try:
#    1218         return tools.to_datetime(pre_parsed)
#
# File parsing.pyx:799, in pandas._libs.tslibs.parsing.try_parse_dates()
#
# TypeError: dateparse() missing 1 required positional argument: 'time_str'

# %% [markdown]
# Q: how to list data entries with negative O3?

# %%
air_quality.O3[air_quality.O3.values < 0]

# %% [markdown]
# Replace negative ozone values with Nan

# %%
air_quality['O3'][air_quality.O3.values < 0] = np.nan

# %% [markdown]
# Saving data to csv:

# %%
air_quality.to_csv("clean_test")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 air_quality.to_csv("clean_test")
#
# NameError: name 'air_quality' is not defined

# %% [markdown]
# # OLR and SOI data
# First we need to import pandas and load the datafiles we want to use for the exercise.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
soi_df = pd.read_csv('../../data/soi.csv', skiprows=1, parse_dates=[0], index_col=0, na_values=-999.9,
                     date_parser=lambda x: pd.datetime.strptime(x, '%Y%m'))
olr_df = pd.read_csv('../../data/olr.csv', skiprows=1, parse_dates=[0], index_col=0, na_values=-999.9,
                     date_parser=lambda x: pd.datetime.strptime(x, '%Y%m'))

# %% [markdown]
# Now that we have the data I will combine them into a single dataframe, as it was done in the Pandas-Intro notebook.

# %%
df = pd.DataFrame({'OLR': olr_df.Value,
                   'SOI': soi_df.Value})
df
# Out:
#             OLR  SOI
# Date
# 1951-01-01  NaN  1.5
# 1951-02-01  NaN  0.9
# 1951-03-01  NaN -0.1
# 1951-04-01  NaN -0.3
# 1951-05-01  NaN -0.7
# ...         ...  ...
# 2016-06-01  0.1  0.6
# 2016-07-01  0.5  0.4
# 2016-08-01  0.8  0.7
# 2016-09-01  0.9  1.2
# 2016-10-01  1.0 -0.3
#
# [790 rows x 2 columns]

# %% [markdown]
# ## Exercise: create a scatter plot

# %% [markdown]
# * You can use `df.plot` function with the appropriate keywords
# * What happens if you use "c=" keyword?
# * Pass another parameter: `edgecolors='none'`

# %% [markdown]
# There are two ways, which I will demonstrate:

# %% [markdown]
# ### First method to create a scatter plot

# %%
# your code here
# the first way is to define the scatter plot with an argument in .plot()
df.plot(kind = 'scatter', x = 'OLR', y = 'SOI')
# Out:
# <AxesSubplot:xlabel='OLR', ylabel='SOI'>

# %% [markdown]
# Note that I had to specify with further arguments which coloumn of the dataframe is the x-axis, and which coloumn is the y-axis.
#
# We can personalise the scatter plot even further using two of the colour arguments: 'c' and 'edgecolor':

# %%
df.plot(kind = 'scatter', x = 'OLR', y = 'SOI', c = 'g', edgecolor = 'k')
# Out:
# <AxesSubplot:xlabel='OLR', ylabel='SOI'>

# %% [markdown]
# As discussed in the teaching notebook, c can take on a range of different kinds of values, for example simple letters or words denoting a colour (e.g. 'g' or 'green') or a third variable with a colourmap (e.g. time). edgecolor defines the color of the edges of the data points, here we chose black, also given by the value 'k'.

# %% [markdown]
# ### Second method to create a scatter plot

# %% [markdown]
# If you prefer to use methods instead of lots of arguments, this works also:

# %%
df
# Out:
#             OLR  SOI
# Date
# 1951-01-01  NaN  1.5
# 1951-02-01  NaN  0.9
# 1951-03-01  NaN -0.1
# 1951-04-01  NaN -0.3
# 1951-05-01  NaN -0.7
# ...         ...  ...
# 2016-06-01  0.1  0.6
# 2016-07-01  0.5  0.4
# 2016-08-01  0.8  0.7
# 2016-09-01  0.9  1.2
# 2016-10-01  1.0 -0.3
#
# [790 rows x 2 columns]

# %%
df.plot.scatter(x='OLR', y='SOI', c='magenta')
# Out:
# <AxesSubplot:xlabel='OLR', ylabel='SOI'>

# %%
import matplotlib.dates as mdates

mdt = mdates.date2num(df.index)

df['mpl_date'] = mdt

ax = df.plot(kind='scatter', x='OLR', y='SOI', c='mpl_date',
             colormap='viridis', colorbar=False, edgecolors='none')
plt.colorbar(ax.collections[0], ticks=mdates.YearLocator(5), 
             format=mdates.DateFormatter('%Y'))

# %% [markdown]
# ## Exercise: Rolling Function

# %% [markdown]
# **1. Subset data**

# %% [markdown]
# * Start by subsetting the SOI `DataFrame`
# * Use either numerical indices, or, even better, datetime indices

# %% [markdown]
# Now to create the subset: say I want to specifically look at the SOI data over the decade 1975-1985:

# %%
# your code here
subset = df['SOI']['1975-01-01':'1985-01-01'] # I selected SOI specifically and used strings to denote the date range in the index.
subset
# Out:
# Date
# 1975-01-01   -0.5
# 1975-02-01    0.8
# 1975-03-01    1.6
# 1975-04-01    1.2
# 1975-05-01    0.6
#              ...
# 1984-09-01    0.1
# 1984-10-01   -0.3
# 1984-11-01    0.3
# 1984-12-01   -0.1
# 1985-01-01   -0.3
# Freq: MS, Name: SOI, Length: 121, dtype: float64

# %%
# let's get an overview of the decade 
subset.describe()
# Out:
# count    121.000000
# mean      -0.024793
# std        1.044612
# min       -3.600000
# 25%       -0.400000
# 50%        0.000000
# 75%        0.600000
# max        2.100000
# Name: SOI, dtype: float64

# %% [markdown]
# **2. Plot the subset data**

# %% [markdown]
# * You can create figure and axis using `matplotlib.pyplot`
# * Or just use the `plot()` method of pandas `DataFrame`

# %%
# your code here
subset.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# **3. Explore what `rolling()` method is**

# %% [markdown]
# * What does this method return?

# %% [markdown]
# We can do a variety of things with the rolling() function. The rolling() method itself will only return a Rolling object, we have to use an additional method to denote what computation we want:

# %%
roll_mean = subset.rolling(12).mean() # here I want to compute a rolling mean over a 12 point rolling window
# note that as the data points are recorded monthly, our window represents a year.
roll_mean
# Out:
# Date
# 1975-01-01         NaN
# 1975-02-01         NaN
# 1975-03-01         NaN
# 1975-04-01         NaN
# 1975-05-01         NaN
#                 ...
# 1984-09-01    0.175000
# 1984-10-01    0.116667
# 1984-11-01    0.150000
# 1984-12-01    0.141667
# 1985-01-01    0.100000
# Freq: MS, Name: SOI, Length: 121, dtype: float64

# %% [markdown]
# **4. Plot the original series and the smoothed series**

# %% [markdown]
# Now we can plot the rolled mean over the original subset:

# %%
# your code here
subset.plot(label = 'Monthly SOI')
roll_mean.plot(label = '12 month-rolling mean SOI')
plt.title('SOI over 10 year period')
plt.legend()
