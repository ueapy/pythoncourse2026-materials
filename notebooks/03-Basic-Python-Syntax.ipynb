# %% [markdown]
# # Python Language Syntax
#
# * Python was originally developed as a teaching language
#
# * The cleanliness of Python's syntax has led some to call it "executable pseudocode"
#
# Syntax refers to the structure of the language (i.e., what constitutes a correctly-formed program).
# For the time being, we'll not focus on the semantics - the meaning of the words and symbols within the syntax - but will return to this at a later point.
#
# ## Example

# %%
# set the midpoint
midpoint = 5

# make two empty lists
lower = []
upper = []

# split the numbers into lower and upper
for i in range(10):
    if (i < midpoint):
        lower.append(i)
    else:
        upper.append(i)
        
print("lower:", lower)
print("upper:", upper)

# %% [markdown]
# This script doesnt do much but it does compactly illustrate several of the important aspects of Python syntax.
# Let's walk through it and discuss it in parts, by the end of this notebook you'll understand every line of it.
#
# ## Comments are marked by ``#``
#
# The script starts with a comment (this means that python won't read this line... but this is very useful to provide information about your code):
# ``` python
# # set the midpoint
# ```
# Comments in Python are indicated by ``#``, and anything on the line following the numbers sign is ignored by the interpreter.
#
# This means, for example, that you can have stand-alone comments like the one just shown, as well as inline comments that follow a statement. For example:
# ``` python
# x += 2  # shorthand for x = x + 2
# ```
# So above, Python reads the first bit of code, but ignores the 'comment' afterwards.
#
#
# ### Comments in other tools
#
# In other editors like VS Code and Spyder, you can use a variant of a comment `#%%` at the start of a line. This creates a section, similar to a notebook cell but inside a plain `.py` script. You may see this in shared code or if you decide to use other IDE's in the future.
#
# You may also see comments like this used as visual dividers to organise long scripts:
#  ```python
# ### ------------------------------------------ ###
# ##               Load Data                       ##
# ### ------------------------------------------ ###
# ```
# or
# ```python
# # ##################### A TITLE #####################
# # ############ A SUBTITLE ############
# # ###### A SUBSUBTITLE ######
# # just a comment
#
# ```
# Python ignores all of this it's purely for human readers, to organise your script!

# %% [markdown]
# Lets give general script commenting a go! Add a comment to each line in the cell below explaining what it does.

# %%
# Add your own comment to this line
temperature = 22.5
print(temperature)
temperature

# %% [markdown]
# ## End-of-line terminates a statement
# The next line in the script is
# ``` python
# midpoint = 5
# ```
# This is an assignment operation, where we've created a variable named ``midpoint`` and assigned it the value ``5``.
# Notice that the end of this statement is simply marked by the end of the line.
#
# In Python, if you'd like a statement to continue to the next line, it is possible to use the "``\``" marker to indicate this:

# %%
x = 1 + 2 + 3 + 4 +\
    5 + 6 + 7 + 8

# %% [markdown]
# It is also possible to continue expressions on the next line within parentheses (or brackets), without using the "``\``" marker:

# %%
x = (1 + 2 + 3 + 4 +
     5 + 6 + 7 + 8)

# %% [markdown]
# The best way is to use the line continuation (within parentheses).
#
# ## Variable assignment
#
# The next lines in our script are:
#
# ```python
# lower = []
# upper = []
# ```
#
# We've seen variable assignment already with `midpoint = 5` and the same idea applies here. We're creating two variables, `lower` and `upper`, and assigning each an empty list `[]` as their starting value. We'll fill them up later in the script.
#
# Note that we write this on two separate lines. One statement per line is standard Python style and keeps your code readable. You may occasionally see this written on a single line:
#
# ```python
# lower = []; upper = []
# ```
#
# This is valid but generally discouraged. There are situations where putting multiple statements on one line makes sense, but for now stick to one per line.

# %% [markdown]
# **Variable naming rules:**
# * Names can contain letters, numbers, and underscores
# * Names cannot start with a number
# * Names cannot contain spaces — use underscores instead (`sea_temp` not `sea temp`)
# * Names are case sensitive (`Temp` and `temp` are different variables)
# * Avoid using Python's reserved words like `for`, `if`, `print`

# %% [markdown]
# ## Indentation matters
#
# Python language uses indentation (whitespace, multiple spaces) to distinguish specific blocks of code.
#
# * Python recognises 4 spaces as indentation
#
# * the top line is the controlling statement
#
# * indented code blocks are always preceded by a colon (``:``)
#
# * anything indented below this top line will occur within it.
#
# For example, the following two snippets will produce different results!

# %%
x = 5
if x < 4:
    y = x * 2
    print(x)

# %%
x = 5
if x < 4:
    y = x * 2
print(x)

# %% [markdown]
# **Exercise:** The code below has an indentation error....fix it so it runs correctly.

# %%
# Check if a temperature is above average
temperature = 18.4
threshold = 15.0

if temperature > threshold:
print("Above threshold")
print(temperature)

# %% [markdown]
# Python's use of meaningful whitespace leads to much more consistent and readable code than languages that do not enforce indentation of code blocks.
#
# ## Whitespace *within* lines does not matter
# While the mantra of *meaningful whitespace* holds true for whitespace *before* lines (which indicate a code block), white space *within* lines of Python code does not matter.
# For example, all three of these expressions are equivalent:

# %%
x=1+2
x = 1 + 2
x             =        1    +                2

# %% [markdown]
# Using whitespace effectively can lead to much more readable code,
# especially in cases where operators follow each other:
#
# *Which one of these do you find easier to read?*
#
# ``` python
# #### Option 1
# x=10**-2
# ```
# to
# ``` python
# #### Option 2
# x = 10 ** -2
# ```
#
#
# Most Python style guides recommend using a single space around binary operators, and no space around unary operators.
#
# **Binary operator:** an operator that works on two values (one on each side) e.g.

# %%
3 + 5       # addition
10 - 4      # subtraction
6 * 7       # multiplication
15 / 3      # division
17 % 5      # modulo (remainder)

x = 3
y = 4
x == y      # equality check

x and y     # logical AND
x or y      # logical OR

# %% [markdown]
# **Unary operator:** an operator that works on just one value (only one side)\
# e.g.

# %%
-x          # negation
not flag    # logical NOT

# %% [markdown]
# We'll discuss Python's operators further in [Basic Python Semantics: Operators](04-Semantics.ipynb).
#
# ## Parentheses are for grouping or calling
#
# In the previous code snippet, we see two uses of parentheses.
# First, they can be used in the typical way to group statements or mathematical operations:

# %%
2 * (3 + 4)

# %% [markdown]
# They can also be used to indicate that a *function* is being called.

# %%
# example
L = [4,2,3,1]

L.sort(reverse=True)
print(L)

# %% [markdown]
# ## Strings
#
# One of the most simple and important aspects of python you will be using constantly will be strings!
#
# Strings are designated by single or double quotation marks.
#
# ``` python
#
# "This is my python string"
#
# 'This is my second python string'
# ```
#
# We will be using 'strings' throughout our whole Python lifetime.
#
# Things to remember:
#
# * Strings are not numbers. You'd have to convert them to a number.

# %%
x = "4" 
print("String: ", type(x),      x)

x = int(x)
print("Integer: ", type(x),    x)

x = float(x)
print("Float: ", type(x),    x)

# %% [markdown]
# ### Triple quotation strings
#
# You may also see strings with triple quotation marks:
#
# ```python
# """This is a multiline
# string"""
#
# '''This is also a multiline
# string'''
# ```
# These have two uses:
# * Writing strings that span multiple lines
# * **Docstrings** — used to document functions and modules. We'll cover these properly when we get to functions.

# %% [markdown]
# ### A note on a ``print()`` function
# > **Note:** If you see `print "hello"` without parentheses in old code, it's Python 2 — in Python 3 `print()` is always a function and always needs brackets.

# %% [markdown]
# ## Exercises
#
# Time to put it into practice! Work through the exercises below — try each one yourself before looking for help.
#
# > **A note on AI tools**
# > Tools like ChatGPT, Claude, and Copilot can be genuinely useful when you're stuck, but they work best when you already understand what you're asking about. For now, try each exercise yourself first. If you're stuck after a few minutes, asking an AI to *explain* what's going wrong and why but make sure you understand the answer before you move on. AI can be a useful learning tool or a second pair of eyes if you just can't see where your code is tripping up in complex scripts.

# %% [markdown]
# ### Exercise 1: Comments and errors

# %%
# Fix this code so it runs and prints the correct output
# Add a comment to each line explaining what it does

temp_celsius = 25
temp_fahrenheit = (temp_celsius * 9/5) + 32 
print(I have calcualted the temperature in fahrenheit)
temp_fahrenheit

# %% [markdown]
# ### Exercise 2: Indentation

# %%
# This code should print a message for each temperature in the list
# Fix it so it runs correctly

reading_1 = 12.1
reading_2 = 18.4
threshold = 15.0

if reading_1 > threshold:
print(reading_1, "is above threshold")

if reading_2 > threshold:
print(reading_2, "is above threshold")

# %% [markdown]
# ### Exercise 3: Using AI to understand an error
#
# Run the cell below — it will produce an error.
#
# Before you paste it into an AI:
# 1. Read the error message — what line is it pointing to? What do you think it means?
# 2. Write your explanation in the cell below
# 3. *Then* paste the error into an AI and ask it to explain what went wrong
# 4. Did the AI explanation match yours? Did it teach you anything new?

# %%
station name = "Buoy 4"
temperature = 18.4

print(station name, "reading:", temperature)

# %% [markdown]
# ## References
# * The most widely used style guide in Python is known as PEP8, and can be found at https://www.python.org/dev/peps/pep-0008/.
#
# * *A Whirlwind Tour of Python* by Jake VanderPlas (O’Reilly). Copyright 2016 O’Reilly Media, Inc., 978-1-491-96465-1
