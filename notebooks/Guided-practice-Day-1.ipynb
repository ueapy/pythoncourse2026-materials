# %% [markdown]
# # Guided Practice

# %% [markdown]
# Now we have some time fo you to try out Python basics that you've just learned.

# %% [markdown]
# ## 1. Operating and testing scalar types int and float

# %% [markdown]
# ### Pizza party!
#
# * Given an number of guests and pizza fraction required per guest
# * Calculate how many pizzas to order
# * Calculate actual pizza fraction per person

# %%
from math import ceil  # ceil() rounds up to nearest integer

num_guests = 3
per_person = 1/3

#num_pizzas = 
#remember to include the person making the order as well!

#print('Order',num_pizzas,'pizzas')
#print('Actual pizzas per person', num_pizzas/(num_guests+1))

# %% [markdown]
# ### Sea level rise
#
# Given the current rate of sea level rise, calculate the predicted sea level in the future.
#
# * `current_sea_level = 0.2` metres above 1980 baseline
# * `rise_per_year = 0.0033` metres per year (current average rate)
# * `years = 50`
#
# Calculate:
# - The predicted sea level in 50 years time relative to the 1980 baseline
# - The total rise over that period
#
# Print both results using f-strings.

# %%
current_sea_level = 0.2    # metres above baseline (already risen since 1900)
rise_per_year = 0.0033     # metres per year (current average rate)
years = 50

# Calculate the predicted sea level in 'years' time
# predicted_level = 

# Calculate the total rise over that period
# total_rise = 

# print your results here!

# %% [markdown]
# ## 2. Explore Booleans
# Booleans can also be constructed using the ``bool()`` object constructor: values of any other type can be converted to Boolean via predictable rules.
# For example, any numeric type is False if equal to zero, and True otherwise:
#
# Before running each line, predict whether it will return `True` or `False`. Write your prediction as a comment, then run the cell to check.
#
# ```python
# bool(1)        # your prediction:
# bool(0)        # your prediction:
# bool(-5)       # your prediction:
# bool(0.0)      # your prediction:
# bool("")       # your prediction:
# bool("hello")  # your prediction:
# bool([])       # your prediction:
# bool([1,2,3])  # your prediction:
# bool(None)     # your prediction:
# ```
#
# Were any of them surprising?

# %%
bool(1)

# %%
bool(0)

# %%
bool(None)

# %%
bool("")

# %%
bool("abc")

# %%
bool([1, 2, 3])

# %%
bool([])

# %% [markdown]
# ## 3. Explore Strings
#
# * Copy a sentence from today's news (or make one up!)
# * Store it as a variable called `news`
# * Replace the spaces with smileys `:)`
# * Print the result

# %%
news = ""  # add your sentence here


# replace spaces with smileys


# print the result

# %% [markdown]
# Now try adding a line to count the number of words in the headline. and print the altered headline and the number of words with an f-string.

# %%
news = ""  # add your sentence here

# count the number of words


# replace spaces with smileys


# print the result using an f-string

# %% [markdown]
# ## 4. Explore Lists

# %% [markdown]
# #### Create
# Store at least 3 different types of objects in a list. For example a string, a number and a float.

# %%
mylist = []  # create your list here

# %% [markdown]
# #### Append
# Add a new element to the end of your list.
# Hint: use `.append()`

# %%
# append an element to mylist

# %% [markdown]
# #### Modify
# Change the first element in your list to something different.
# Hint: you can access the first element with `mylist[0]`

# %%
# modify the first element

# %% [markdown]
# #### Slice
# Create a new list containing only the first 3 elements of your list.

# %%
# create a new list with the first 3 elements

# %% [markdown]
# ### Reverse
# Create a new list that is the reverse of your list.
#
# Watch out! Try this first:
# ```python
# revlist = mylist.reverse()
# print(revlist)
# ```
# Why does it print `None`? How would you fix it?

# %%
# try reversing your list here

# %% [markdown]
# ## 5. Sequence comprehensions
#
# #### Exercise 1:
# * Starting by creating a list of Olympic Games years starting in 1948
# * Create a list with the predicted Football world Cup years, which is held 2 years after each Olympic Games.
#
# Hint: use `range()` and a list comprehension

# %%
# create the olympics list

# create the world cup list using a list comprehension

# %% [markdown]
# #### Exercise 2:
# * Use the list of country names below
# * Create a new list where each country name is capitalised correctly
#
# Hint: u `.capitalize() .title()` may help you
#
# How do you think it will handle El Salvador as it is 2 words?

# %%
countries = ['paRaguay', 'uRUGUAY', 'SPAIN', 'chile', 'el Salvador']

# your code here

# %% [markdown]
# #### Exercise 3:
# * Use the dictionary of battles below
# * Create a list of years that are in the 19th century (between 1800 and 1900)
#
# Hint: use `.values()` to access the years

# %%
Battles = {'Austerlitz':1805, 'Alkmaar':1799, 'Arhem':1813, 'Arcole':1796, 'Jena':1806}

# list of years in the 19th century

# %% [markdown]
# * Using the same dictionary, create a list of battle **names** from the 19th century (>1800)
#
# Hint: use `.items()` or `.keys()`

# %%
# list of battle names in the 19th century

# %% [markdown]
# ## 6. Dictionaries
#
# Store the following information in a dictionary:
# * pet's name, age, colour and weight
#
# Set the weight to `None` for now  we'll fill it in later!

# %%
# mypet = {'name':    }

# %% [markdown]
# Now:
# * Update the weight to a real value
# * Add a new key: `species`
# * Print a formatted sentence about your pet using an f-string e.g. `"My pet is called X, they are a Y and weigh Z kg"`

# %%
# update weight

# add species as an attribute

# print a formatted sentence

# %% [markdown]
# ## 7.1 Putting it all together — Field Survey Summary
#
# You've collected data from 5 survey stations. Using everything you've learned today, build a mini survey summary.
#
# ```python
# stations = ['NorthSea_01', 'NorthSea_02', 'NorthSea_03', 'NorthSea_04', 'NorthSea_05']
# temperatures = [8.2, 7.9, 9.1, 6.8, 8.5]   # celsius
# salinities = [34.2, 35.1, 33.8, 35.6, 34.9] # PSU
# ```
#
# **Tasks:**
# 1. Create a new list of station names in uppercase
# 2. Calculate the mean temperature (hint: use `sum()` and `len()`)
# 3. Create a list of temperatures that are above the mean
# 4. Build a dictionary for the first station containing its name, temperature and salinity
# 5. Print a formatted summary using f-strings, e.g:
#    * Number of stations
#    * Mean temperature
#    * How many stations are

# %%
stations = ['NorthSea_01', 'NorthSea_02', 'NorthSea_03', 'NorthSea_04', 'NorthSea_05']
temperatures = [8.2, 7.9, 9.1, 6.8, 8.5]   # celsius
salinities = [34.2, 35.1, 33.8, 35.6, 34.9] # PSU

# 1. Create a list of station names in uppercase


# 2. Calculate the mean temperature


# 3. Create a list of temperatures above the mean


# 4. Build a dictionary for the first station


# 5. Print a formatted summary

# %% [markdown]
# ## 7.2 Using AI to extend your program
#
# You've built a working survey summary - now use an AI tool (Claude, ChatGPT, Copilot) to help you add a new feature.
#
# Here are some ideas to ask it:
# * *"Find the station with the highest temperature"*
# * *"Find the station with the lowest salinity"*
# * *"Create a list of dictionaries — one per station — containing all the data"*
#
# **Before you use the AI's answer:**
# 1. Read through the code carefully — does it make sense?
# 2. Can you understand every line?
# 3. Run it and check the output is what you expected
#
# > **Remember** - you now know enough Python to check whether the answer is correct. AI can and does make mistakes - your job is to spot them!

# %%
# Paste and test the AI's code here
